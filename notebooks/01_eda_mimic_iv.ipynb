# %% [markdown]
# # EDA MIMIC-IV
#
# Notebook mỏng để xem nhanh schema raw và vocab sau preprocess.

# %%
from pathlib import Path

from src.utils.io import read_json

project_root = Path.cwd().resolve().parents[0] if Path.cwd().name == 'notebooks' else Path.cwd()
vocab_dir = project_root / 'data' / 'interim' / 'vocab'
summary = read_json(vocab_dir / 'vocab_summary.json')
summary

# %%
lab_metadata = read_json(vocab_dir / 'lab_metadata.json')
list(lab_metadata.items())[:10]
